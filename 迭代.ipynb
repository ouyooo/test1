# %%
def for_loop(n: int) -> int:
    """for 循环"""
    res = 0
    # 循环求和 1, 2, ..., n-1, n
    for i in range(1, n + 1):
        res += i
    return res

"""Driver Code"""
if __name__ == "__main__":
    n = 4
    res = for_loop(n)
    print(f"\nfor 循环的求和结果 res = {res}")
# Out:
# for 循环的求和结果 res = 10

# %%
def while_loop(n: int) -> int:
    """while 循环"""
    res = 0
    i = 1  # 初始化条件变量
    # 循环求和 1, 2, ..., n-1, n
    while i <= n:
        res += i
        i += 1  # 更新条件变量
    return res

"""Driver Code"""
if __name__ == "__main__":
    n = 4
    res = while_loop(n)
    print(f"\nwhile 循环的求和结果 res = {res}")
# Out:
# while 循环的求和结果 res = 10

# %%
def while_loop_ii(n: int) -> int:
    """while 循环（两次更新）"""
    res = 0
    i = 1  # 初始化条件变量
    # 循环求和 1, 4, 10, ...
    while i <= n:
        res += i
        # 更新条件变量
        i += 1
        i *= 2
    return res

"""Driver Code"""
if __name__ == "__main__":
    n = 5
    res = while_loop_ii(n)
    print(f"\n 每轮2次更新的求和结果 res = {res}")
# Out:
#  每轮2次更新的求和结果 res = 5

# %%
def nested_for_loop(n: int) -> str:
    """双层 for 循环"""
    res = ""
    # 循环 i = 1, 2, ..., n-1, n
    for i in range(1, n + 1):
        # 循环 j = 1, 2, ..., n-1, n
        for j in range(1, n + 1):
            res += f"({i}, {j}), "
    return res

"""Driver Code"""
if __name__ == "__main__":
    n = 5
    res = nested_for_loop(n)
    print(f"\n 嵌套的求和结果 res = {res}")
    
    """算法运行时间和输入数据大小  成“平方关系”,再嵌套--四次方"""
# Out:
#  嵌套的求和结果 res = (1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 1), (2, 2), (2, 3), (2, 4), (2, 5), (3, 1), (3, 2), (3, 3), (3, 4), (3, 5), (4, 1), (4, 2), (4, 3), (4, 4), (4, 5), (5, 1), (5, 2), (5, 3), (5, 4), (5, 5),
